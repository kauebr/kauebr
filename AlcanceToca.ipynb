# %%
import pandas as pd
df = pd.read_csv('AlcanceFbook.csv', encoding='latin1', sep=';')
pd.set_option('display.max_rows', 100)
display(df)
# Out:
#      Hora da publicação         Tipo de conteúdo  Alcance  Curtidas e reações  \
# 0   2021-03-03T12:21:55   Publicação do Facebook   346808                2785
# 1   2021-07-23T07:57:40   Publicação do Facebook   109884                 704
# 2   2021-10-12T09:26:51   Publicação do Facebook    72979                 408
# 3   2021-03-12T16:54:07   Publicação do Facebook    68806                 367
# 4   2020-09-10T14:38:12   Publicação do Facebook    55300                 282
# 5   2021-04-14T03:44:25   Publicação do Facebook    41391                 280
# 6   2021-09-17T12:24:29   Publicação do Facebook     9769                  99
# 7   2021-08-30T12:49:27   Publicação do Facebook     8134                  87
# 8   2021-04-21T09:16:54                  Anúncio     6637                  62
# 9   2020-10-19T16:38:12   Publicação do Facebook     6054                  18
# 10  2021-03-10T06:21:12   Publicação do Facebook     5928                  82
# ...
